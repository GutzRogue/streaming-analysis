# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("Analyse Abonnes")
    .getOrCreate()
)

spark

# %%
df = spark.read.csv(
    "hdfs://namenode:9000/data/abonnes.csv",
    header=True,
    inferSchema=True
)

df.show()
# Out:
# +---------+----------+---+----------+----------------------+-------+
# |id_abonne|     ville|age|abonnement|duree_utilisation_mois|montant|
# +---------+----------+---+----------+----------------------+-------+
# |        1|     Rabat| 19|   Premium|                    16| 261.05|
# |        2|     Rabat| 61|     Basic|                    38| 449.83|
# |        3|Casablanca| 23|  Standard|                    15| 529.09|
# |        4|Casablanca| 53|  Standard|                    46| 666.39|
# |        5|   Kenitra| 44|  Standard|                    29|  608.8|
# |        6|Casablanca| 66|  Standard|                    45| 450.48|
# |        7|    Agadir| 27|  Standard|                    49| 368.76|
# |        8|     Rabat| 42|     Basic|                    23| 854.12|
# |        9|    Meknes| 34|     Basic|                    47| 485.45|
# |       10|     Rabat| 42|     Basic|                    36| 327.52|
# |       11|    Meknes| 74|   Premium|                    37| 231.67|
# |       12|     Rabat| 20|  Standard|                    50| 323.92|
# |       13|     Rabat| 72|  Standard|                    56| 144.95|
# |       14|    Agadir| 47|   Premium|                    11| 400.67|
# |       15| Marrakech| 60|   Premium|                    45| 938.82|
# |       16|     Rabat| 56|  Standard|                    35| 741.67|
# |       17|       Fes| 47|   Famille|                    18| 989.05|
# |       18|   Kenitra| 32|   Premium|                    54|  778.9|
# |       19|Casablanca| 32|     Basic|                    52| 348.68|
# |       20|    Agadir| 22|  Standard|                    59| 944.76|
# +---------+----------+---+----------+----------------------+-------+
# only showing top 20 rows
